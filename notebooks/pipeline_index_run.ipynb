# %%
import index

# %%
# Index theo từng lĩnh vực, mỗi lĩnh vực là một db riêng
if __name__ == "__main__":
    total_chunks = index.build_and_index(
        db_path="./lao_dong_tien_luong",
        collection_name="lao_dong_tien_luong",
        sector="Lao động - Tiền lương",
    )
    print(f"Indexed {total_chunks} chunks into ChromaDB.")
